# %% [markdown]
# <a href="https://colab.research.google.com/github/jesusvillota/CSS_DataScience_2025/blob/main/Session3/3_4_LLM_II_Function_Calling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="max-width: 880px; margin: 20px auto 22px; padding: 0px; border-radius: 18px; border: 1px solid #e5e7eb; background: linear-gradient(180deg, #ffffff 0%, #f9fafb 100%); box-shadow: 0 8px 26px rgba(0,0,0,0.06); overflow: hidden;">
#
#   <!-- Banner Header -->
#   <div style="padding: 34px 32px 14px; text-align: center; line-height: 1.38;">
#     <div style="font-size: 13px; letter-spacing: 0.14em; text-transform: uppercase; color: #6b7280; font-weight: bold; margin-bottom: 5px;">
#       Session #3
#     </div>
#     <div style="font-size: 29px; font-weight: 800; color: #14276c; margin-bottom: 4px;">
#       LLMs
#     </div>
#     <div style="font-size: 26px; font-weight: 800; color: #14276c; margin-bottom: 4px;">
#       Part II: Function Calling
#     </div>
#     <div style="font-size: 16.5px; color: #374151; font-style: italic; margin-bottom: 0;">
#       Using Textual Data in Empirical Monetary Economics
#     </div>
#   </div>
#
#   <!-- Logo Section -->
#   <div style="background: none; text-align: center; margin: 30px 0 10px;">
#     <img src="https://www.cemfi.es/images/Logo-Azul.png" alt="CEMFI Logo" style="width: 158px; filter: drop-shadow(0 2px 12px rgba(56,84,156,0.05)); margin-bottom: 0;">
#   </div>
#
#   <!-- Name -->
#   <div style="font-family: 'Times New Roman', Times, serif; color: #38549c; text-align: center; font-size: 1.22em; font-weight: bold; margin-bottom: 0px;">
#     Jesus Villota Miranda © 2025
#   </div>
#
#   <!-- Contact info -->
#   <div style="font-family: 'Times New Roman', Times, serif; color: #38549c; text-align: center; font-size: 1em; margin-top: 7px; margin-bottom: 20px;">
#     <a href="mailto:jesus.villota@cemfi.edu.es" style="color: #38549c; text-decoration: none; margin-right:8px;" title="Email">
#       <!-- <img src="https://cdn-icons-png.flaticon.com/512/11679/11679732.png" alt="Email" style="width:18px; vertical-align:middle; margin-right:5px;"> -->
#       jesus.villota@cemfi.edu.es
#     </a>
#     <span style="color:#9fa7bd;">|</span>
#     <a href="https://www.linkedin.com/in/jesusvillotamiranda/" target="_blank" style="color: #38549c; text-decoration: none; margin-left:7px;" title="LinkedIn">
#       <!-- <img src="https://1.bp.blogspot.com/-onvhHUdW1Us/YI52e9j4eKI/AAAAAAAAE4c/6s9wzOpIDYcAo4YmTX1Qg51OlwMFmilFACLcBGAsYHQ/s1600/Logo%2BLinkedin.png" alt="LinkedIn" style="width:17px; vertical-align:middle; margin-right:5px;"> -->
#       LinkedIn
#     </a>
#   </div>
# </div>

# %% [markdown]
# **IMPORTANT**: **Are you running this notebook in Google Colab?**
#
# - If so, please make sure that in the cell below `running_in_colab` is set to `True`
#
# - And, of course,  make sure to **run the cell**!

# %%
running_in_colab = False

# %% [markdown]
# ## What we'll be doing here (big picture)
#
#
#
# - Goal: show how “function calling” lets an LLM return structured data by invoking your Python functions with validated arguments.
#
# - We’ll build two small applications:
#
#   1) News → firm-level shocks: from a Spanish article, extract affected Spanish listed firms and classify shock type/magnitude/direction.
#
#   2) Constitution articles → camera-implied tasks: decide whether a constitutional article assigns/impllies tasks to Congress, Senate, both, or neither.
#
# - Core pattern you’ll see in both:
#
#   1) Define a tool schema (name, description, JSON parameters) for the function you want the model to call.
#
#   2) Ask the LLM with tools enabled; if it decides to call your tool, it provides JSON args matching the schema.
#
#   3) Validate/execute your local Python function; return its result to the model as a tool response.
#
#   4) Make a second model call so the LLM can integrate the tool’s structured output into a final answer.

# %%
import os
import json
import pandas as pd

if running_in_colab:
    ! pip install groq
    from google.colab import userdata
    api_key = userdata.get('GROQ_API_KEY')
else:
    import os
    from dotenv import load_dotenv
    load_dotenv()
    api_key = os.getenv('GROQ_API_KEY')

# %%
from groq import Groq
client = Groq(api_key=api_key)
MODEL = 'llama3-70b-8192'

# %% [markdown]
# <div style="max-width: 880px; margin: 20px auto 22px; padding: 20px 32px; border-radius: 18px; border: 1px solid #e5e7eb; background: linear-gradient(180deg, #ffffff 0%, #f9fafb 100%); box-shadow: 0 8px 26px rgba(0,0,0,0.06); overflow: hidden; text-align: center;">
#
#   <div style="font-size: 20px; font-weight: 800; color: #14276c; margin-bottom: 8px;">
#     Application #1)
#   </div>
#   <div style="font-size: 18px; font-weight: 700; color: #374151; font-style: italic;">
#     Extracting & categorizing news-implied firm-specific shocks
#   </div>
#
# </div>

# %% [markdown]
# This notebook replicates the methodology in [CEMFI Working Paper 2501](https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5006857).

# %%
def news_parser(firms):
    response = []
    for firm in firms:
        response.append({
            "firm": firm["firm"],
            "ticker": firm.get("ticker", ""),
            "shock_type": firm.get("shock_type", ""),
            "shock_magnitude": firm.get("shock_magnitude", ""),
            "shock_direction": firm.get("shock_direction", ""),
        })
    return response

def run_conversation(user_prompt):
    # Step 1: send the conversation and available functions to the model
    messages = [
        {
            "role": "system",
            "content":  f"""
                            You are a function calling LLM that analyses business news in Spanish. 
                        """
        },
        {
            "role": "user",
            "content": user_prompt,
        }
    ]
    
    tools = [
        {
            "type": "function",
            "function": {
                "name": "news_parser",
                "description": f"""
                                    For every article, you must identify the firms directly affected by the news. Do not include every firm mentioned in the article, only include those that are directly affected by the shocks narrated therein. 
                                    The identified firms must be Spanish and should be publicly listed in the Spanish exchange (their ticker is of the form 'TICKER.MC'). Do not include non-Spanish foreign firms. Do not include Spanish firms that are not publicly traded.
                                    For each identified firm, classify the shocks that affect them (type, magnitude, category). The type of shock can be 'demand', 'supply', 'financial', 'policy', or 'technology'. The magnitude can be 'minor' or 'major'. The direction can be 'positive' or 'negative'.
                                    If a firm is neutral to the article, do NOT include it in the analysis.
                                """,
                "parameters": {
                    "type": "object",
                    "properties": {
                        "firms": {
                            "type": "array",
                            "description": f"""
                                                List the Spanish firms impacted by the reported news. Such firms must be publicly listed in the Spanish stock exchange and have a stock market ticker of the form TICKER.MC. 
                                                Foreign firms (not listed in the Spanish exchange and whose ticker is not TICKER.MC) are not to be included here. Do not include firms that are mentioned just for contextual comparison but are not directly affected by the events described in the article.
                                                If a firm is neutral to the article, do not include it in the list.
                                                Some times the article mentions explicitly the Spanish ticker of those firms that are directly affected (and hence, the firms to include here). e.g: Iberdrola (IBE.MC).
                                            """,
                            "items": {
                                "type": "object",
                                "properties": {
                                    "firm": {
                                        "type": "string",
                                        "description": "State the Spanish firm (within the list 'firms') in which you will focus the analysis. This firm should be publicly traded in the Spanish exchange with a ticker of the form 'TICKER.MC'. ",
                                    },
                                    "ticker": {
                                        "type": "string",
                                        "description": "Specify its stock market ticker of the Spanish firm in Yahoo Finance format (note that Spanish firms' tickers end with '.MC', e.g., ITX.MC for Inditex, ACX.MC for Acerinox, SAN.MC for Banco Santander, NTGY.MC for Naturgy).",
                                    },
                                    "shock_type": {
                                        "type": "string",
                                        "enum": ["demand", "supply", "financial", "policy", "technology"],
                                        "description": "Classify the type of shock implied by the news article. Choose 'demand' for events impacting consumer demand, 'supply' for events affecting the supply of goods or services, 'financial' for events related to financial markets or conditions, 'policy' for events stemming from changes in government policies or regulations, and 'technology' for events resulting from significant technological advancements or disruptions.",
                                    },
                                    "shock_magnitude": {
                                        "type": "string",
                                        "enum": ["minor", "major"],
                                        "description": "How strong do you expect the shock to be: 'minor' or 'major'?",
                                    },
                                    "shock_direction": {
                                        "type": "string",
                                        "enum": ["positive", "negative"],
                                        "description": f"""
                                                        In what direction do you expect the shock to affect this firm? Choose one of the available options: 'positive' or 'negative'.
                                                        Choose 'positive' for beneficial impacts and 'negative' for adverse impacts.
                                                        Do not state 'neutral' here. If the firm is neutral to the article, do not include it in the list of firms.
                                                        """,
                                    },
                                },
                                "required": ["firm"],
                            },
                        },
                    },
                    "required": ["firms"],
                },
            },
        },
    ]

    response = client.chat.completions.create(
        model=MODEL,
        messages=messages,
        tools=tools,
        tool_choice="auto",
        max_tokens=4096
    )

    response_message = response.choices[0].message
    tool_calls = response_message.tool_calls
    
    # Step 2: check if the model wanted to call a function
    if tool_calls:
        
        # Step 3: call the function
        available_functions = {
            "news_parser": news_parser,
        }
        messages.append(response_message)  # extend conversation with assistant's reply
        
        # Step 4: send the info for each function call and function response to the model
        for tool_call in tool_calls:
            function_name = tool_call.function.name
            function_to_call = available_functions[function_name]
            function_args = json.loads(tool_call.function.arguments)
            function_response = function_to_call(
                firms=function_args.get("firms")
            )
            messages.append(
                {
                    "role": "function",
                    "name": function_name,
                    "content": json.dumps(function_response),
                }
            )  # extend conversation with function response
        second_response = client.chat.completions.create(
            model=MODEL,
            messages=messages
        )  # get a new response from the model where it can see the function response
        
        return second_response.choices[0].message.content, function_response


user_prompt = f"""
Cellnex tendrá más competencia en Europa.  La filial de Telefónica (TEF.MC) Telxius Telecom ha acordado vender su división de torres de telecomunicaciones en Europa y Latinoamérica a American Tower (AMT), lo cual aumentará la presencia de ésta en Europa e incrementará la competencia para el grupo español de telecomunicaciones inalámbricas Cellnex Telecom (CLNX.MC), señala Equita Sim. La transacción "supone la entrada de un nuevo operador independiente de torres en el mercado español y potencialmente más competencia para el crecimiento futuro también en el mercado europeo", sostiene la correduría. Cellnex llegó a un acuerdo en noviembre con CK Hutchison (0001.HK) para comprar el negocio europeo de torres y sus activos del conglomerado cotizado en Hong Kong. La acción de Telefónica sube un 9,6% a EUR3,94 y la de Cellnex avanza un 0,3% a EUR47,79.
"""

completion_text, structured_output = run_conversation(user_prompt)
print("Completion Text:", completion_text)
print("Structured Output:", structured_output)
# Out:
# Completion Text: The function call has been successful. The output is a list of two dictionaries, each representing a firm mentioned in the news article.
#
# The first dictionary corresponds to Cellnex Telecom, indicating that the firm is expected to experience a negative supply shock of minor magnitude, which means that the company may face increased competition in the European market.
#
# The second dictionary corresponds to Telefónica, indicating that the firm is expected to experience a positive financial shock of minor magnitude, which means that the sale of its tower division to American Tower is likely to have a beneficial impact on its financial performance.
#
# This analysis can be useful for investors, analysts, and other stakeholders to assess the potential impact of this news on the stock prices and business prospects of these companies.
# Structured Output: [{'firm': 'Cellnex Telecom', 'ticker': 'CLNX.MC', 'shock_type': 'supply', 'shock_magnitude': 'minor', 'shock_direction': 'negative'}, {'firm': 'Telefónica', 'ticker': 'TEF.MC', 'shock_type': 'financial', 'shock_magnitude': 'minor', 'shock_direction': 'positive'}]

# %%
structured_output
# Out:
# [{'firm': 'Cellnex Telecom',
#   'ticker': 'CLNX.MC',
#   'shock_type': 'supply',
#   'shock_magnitude': 'minor',
#   'shock_direction': 'negative'},
#  {'firm': 'Telefónica',
#   'ticker': 'TEF.MC',
#   'shock_type': 'financial',
#   'shock_magnitude': 'minor',
#   'shock_direction': 'positive'}]

# %% [markdown]
# <div style="max-width: 880px; margin: 20px auto 22px; padding: 20px 32px; border-radius: 18px; border: 1px solid #e5e7eb; background: linear-gradient(180deg, #ffffff 0%, #f9fafb 100%); box-shadow: 0 8px 26px rgba(0,0,0,0.06); overflow: hidden; text-align: center;">
#
#   <div style="font-size: 20px; font-weight: 800; color: #14276c; margin-bottom: 8px;">
#     Application #2
#   </div>
#   <div style="font-size: 18px; font-weight: 700; color: #374151; font-style: italic;">
#     Extracting the camera-implied task in each article of Argentina's Constitution (Extra)
#   </div>
#
# </div>

# %%
import PyPDF2
import re

def extract_text_from_pdf(file_path):
    with open(file_path, "rb") as file:
        reader = PyPDF2.PdfReader(file)
        text = ""
        for page in reader.pages:
            text += page.extract_text()
    return text

def split_into_articles(text):
    # Normalize text to lowercase to capture "articulo" consistently
    text = text.lower()

    # Find the start index of "disposiciones transitorias" to ignore it and anything after
    disp_trans_index = text.find("disposiciones transitorias")
    if disp_trans_index != -1:
        text = text[:disp_trans_index]

    # Use regex to split on "articulo X" where X is a number, capturing each article
    # The pattern captures the article header and the content until the next article or end of text
    pattern = re.compile(r"(artículo \d+.*?)(?=artículo \d+|$)", re.DOTALL)

    articles = pattern.findall(text)

    # Strip whitespace from articles
    articles = [article.strip() for article in articles if article.strip()]

    return articles

# %%
# Read the constitution (stored in Session3/docs/constitucion.pdf)
file_path = "docs/constitucion.pdf"
full_text = extract_text_from_pdf(file_path)

# Separate the full text (string) into a list of articles (strings)
articles_list = split_into_articles(full_text)
articles_list
# Out:
# ['artículo 1.- la nación argentina adopta para su gob ierno la forma representativa republicana \nfederal, según lo establece la presente constitució n.',
#  'artículo 2.- el gobierno federal sostiene el culto católico apostólico romano.',
#  'artículo 3.- las autoridades que ejercen el gobiern o federal, residen en la ciudad que se \ndeclare capital de la república por una ley especia l del congreso, previa cesión hecha por una o \nmas legislaturas provinciales, del territorio que h aya de federalizarse.',
#  'artículo 4.- el gobierno federal provee a los gasto s de la nación con los fondos del tesoro \nnacional formado del producto de derechos de import ación y exportación, del de la venta o \nlocación de tierras de propiedad nacional, de la re nta de correos, de las demás contribuciones \nque equitativa y proporcionalmente a la población i mponga el congreso general, y de los \nempréstitos y operaciones de crédito que decrete el  mismo congreso para urgencias de la \nnación, o para empresas de utilidad nacional.',
#  'artículo 5.- cada provincia dictará para sí una con stitución bajo el sistema representativo \nrepublicano, de acuerdo con los principios, declara ciones y garantías de la constitución \nnacional; y que asegure su administración de justic ia, su régimen municipal, y la educación \nprimaria. bajo de estas condiciones el gobierno fed eral, garante a cada provincia el goce y \nejercicio de sus instituciones.',
#  'artículo 6.- el gobierno federal interviene en el t erritorio de las provincias para garantir la \nforma republicana de gobierno, o repeler invasiones  exteriores, y a requisición de sus \nautoridades constituidas para sostenerlas o restabl ecerlas, si hubiesen sido depuestas por la \nsedición, o por invasión de otra provincia.',
#  'artículo 7.- los actos públicos y procedimientos ju diciales de una provincia gozan de entera \nfe en las demás; y el congreso puede por leyes gene rales determinar cuál será la forma \nprobatoria de estos actos y procedimientos, y los e fectos legales que producirán.',
#  'artículo 8.- los ciudadanos de cada provincia gozan  de todos los derechos, privilegios e \ninmunidades inherentes al título de ciudadano en la s demás. la extradición de los criminales es \nde obligación recíproca entre todas las provincias.',
#  'artículo 9.- en todo el territorio de la nación no habrá más aduanas que las nacionales, en \nlas cuales regirán las tarifas que sancione el cong reso.',
#  'artículo 10.- en el interior de la república es lib re de derechos la circulación de los efectos \nde producción o fabricación nacional, así como la d e los géneros y mercancías de todas clases, \ndespachadas en las aduanas exteriores.',
#  'artículo 11.- los artículos de producción o fabrica ción nacional o extranjera, así como los \nganados de toda especie, que pasen por territorio d e una provincia a otra, serán libres de los \nderechos llamados de tránsito, siéndolo también los  carruajes, buques o bestias en que se \ntransporten; y ningún otro derecho podrá imponérsel es en adelante, cualquiera que sea su \ndenominación, por el hecho de transitar el territor io.',
#  'artículo 12.- los buques destinados de una provinci a a otra, no serán obligados a entrar, \nanclar y pagar derechos por causa de tránsito, sin que en ningún caso puedan concederse \npreferencias a un puerto respecto de otro, por medi o de leyes o reglamentos de comercio.',
#  'artículo 13.- podrán admitirse nuevas provincias en  la nación; pero no podrá erigirse una \nprovincia en el territorio de otra u otras, ni de v arias formarse una sola, sin el consentimiento de \nla legislatura de las provincias interesadas y del congreso.',
#  'artículo 14.- todos los habitantes de la nación goz an de los siguientes derechos conforme a \nlas leyes que reglamenten su ejercicio; a saber: \nde trabajar y ejercer toda industria lícita; de nav egar y comerciar; de peticionar a las autoridades; \nde entrar, permanecer, transitar y salir del territ orio argentino; de publicar sus ideas por la prensa  \nsin censura previa; de usar y disponer de su propie dad; de asociarse con fines útiles; de profesar \nlibremente su culto; de enseñar y aprender.',
#  'artículo 14 bis.- el trabajo en sus diversas formas  gozará de la protección de las leyes, las \nque asegurarán al trabajador: condiciones dignas y equitativas de labor; jornada limitada; \ndescanso y vacaciones pagados; \nretribución justa; salario mínimo, vital móvil, igu al remuneración por igual tarea; participación en \nlas ganancias de las empresas, con control de la pr oducción y colaboración en la dirección; \nprotección contra el despido arbitrario; estabilida d del empleado público; \norganización sindical libre y democrática, reconoci da por la simple inscripción en un registro \nespecial. queda garantizado a los gremios: \nconcertar convenios colectivos de trabajo; recurrir  a la conciliación y al arbitraje; el derecho de \nhuelga. los representantes gremiales gozarán de las  garantías necesarias para el cumplimiento \nde su gestión sindical y la relacionada con la esta bilidad de su empleo. el estado otorgará los \nbeneficios de la seguridad social, que tendrá carác ter de integral e irrenunciable. en especial la \nley establecerá: el seguro social obligatorio, que estará a cargo de entidades nacionales o \nprovinciales con autonomía financiera y económica, administradas por los interesados con \nparticipación del estado, sin que pueda existir sup erposición de aportes; jubilaciones y pensiones \nmóviles; la protección integral de la familia; la d efensa del bien de familia; la compensación \neconómica familiar y el acceso a una vivienda digna .',
#  'artículo 15.- en la nación argentina no hay esclavo s; los pocos que hoy existen quedan \nlibres desde la jura de esta constitución; y una le y especial reglará las indemnizaciones a que dé \nlugar esta declaración. todo contrato de compra y venta de personas es un c rimen de que serán responsables los que \nlo celebrasen, y el escribano o funcionario que lo autorice. y los esclavos que de cualquier modo \nse introduzcan quedan libres por el solo hecho de p isar el territorio de la república.',
#  'artículo 16.- la nación argentina no admite prerrog ativas de sangre, ni de nacimiento: no \nhay en ella fueros personales ni títulos de nobleza . \ntodos sus habitantes son iguales ante la ley, y adm isibles en los empleos sin otra condición que \nla idoneidad. la igualdad es la base del impuesto y  de las cargas públicas.',
#  'artículo 17.- la propiedad es inviolable, y ningún habitante de la nación puede ser privado de \nella, sino en virtud de sentencia fundada en ley. \nla expropiación por causa de utilidad pública, debe  ser calificada por ley y previamente \nindemnizada. sólo el congreso impone las contribuci ones que se expresan en el',
#  'artículo 4. \nningún servicio personal es exigible, sino en virtu d de ley o de sentencia fundada en ley. todo \nautor o inventor es propietario exclusivo de su obr a, invento o descubrimiento, por el término que \nle acuerde la ley. la confiscación de bienes queda borrada para siempre del código penal \nargentino. ningún cuerpo armado puede hacer resquis iciones, ni exigir auxilios de ninguna \nespecie.',
#  'artículo 18.- ningún habitante de la nación puede s er penado sin juicio previo fundado en ley \nanterior al hecho del proceso, ni juzgado por comis iones especiales, o sacado de los jueces \ndesignados por la ley antes del hecho de la causa. nadie puede ser obligado a declarar contra sí \nmismo; ni arrestado sino en virtud de orden escrita  de autoridad competente. es inviolable la \ndefensa en juicio de la persona y de los derechos. el domicilio es inviolable, como también la \ncorrespondencia epistolar y los papeles privados; y  una ley determinará en qué casos y con qué \njustificativos podrá procederse a su allanamiento y  ocupación. quedan abolidos para siempre la \npena de muerte por causas políticas, toda especie d e tormento y los azotes. las cárceles de la \nnación serán sanas y limpias, para seguridad y no p ara castigo de los reos detenidos en ellas, y \ntoda medida que a pretexto de precaución conduzca a  mortificarlos más allá de lo que aquélla \nexija, hará responsable al juez que la autorice.',
#  'artículo 19.- las acciones privadas de los hombres que de ningún modo ofendan al orden y a \nla moral pública, ni perjudiquen a un tercero, está n sólo reservadas a dios, y exentas de la \nautoridad de los magistrados. ningún habitante de l a nación será obligado a hacer lo que no \nmanda la ley, ni privado de lo que ella no prohíbe.',
#  'artículo 20.- los extranjeros gozan en el territori o de la nación de todos los derechos civiles \ndel ciudadano; pueden ejercer su industria, comerci o y profesión; poseer bienes raíces, \ncomprarlos y enajenarlos; \nnavegar los ríos y costas; ejercer libremente su cu lto; testar y casarse conforme a las leyes. no \nestán obligados a admitir la ciudadanía, ni a pagar  contribuciones forzosas extraordinarias. \nobtienen nacionalización residiendo dos años contin uos en la nación; pero la autoridad puede \nacortar este término a favor del que lo solicite, a legando y probando servicios a la república.',
#  'artículo 21.- todo ciudadano argentino está obligad o a armarse en defensa de la patria y de \nesta constitución, conforme a las leyes que al efec to dicte el congreso y a los decretos del \nejecutivo nacional. los ciudadanos por naturalizaci ón son libres de prestar o no este servicio por \nel término de diez años contados desde el día en qu e obtengan su carta de ciudadanía.',
#  'artículo 22.- el pueblo no delibera ni gobierna, si no por medio de sus representantes y \nautoridades creadas por esta constitución. toda fue rza armada o reunión de personas que se \natribuya los derechos del pueblo y peticione a nomb re de éste, comete delito de sedición.',
#  'artículo 23.- en caso de conmoción interior o de at aque exterior que pongan en peligro el \nejercicio de esta constitución y de las autoridades  creadas por ella, se declarará en estado de \nsitio la provincia o territorio en donde exista la perturbación del orden, quedando suspensas allí \nlas garantías constitucionales. pero durante esta s uspensión no podrá el presidente de la \nrepública condenar por sí ni aplicar penas. su pode r se limitará en tal caso respecto de las \npersonas, a arrestarlas o trasladarlas de un punto a otro de la nación, si ellas no prefiriesen salir \nfuera del territorio argentino.',
#  'artículo 24.- el congreso promoverá la reforma de l a actual legislación en todos sus ramos, y \nel establecimiento del juicio por jurados.',
#  'artículo 25.- el gobierno federal fomentará la inmi gración europea; y no podrá restringir, \nlimitar ni gravar con impuesto alguno la entrada en  el territorio argentino de los extranjeros que \ntraigan por objeto labrar la tierra, mejorar las in dustrias, e introducir y enseñar las ciencias y las  \nartes.',
#  'artículo 26.- la navegación de los ríos interiores de la nación es libre para todas las \nbanderas, con sujeción únicamente a los reglamentos  que dicte la autoridad nacional.',
#  'artículo 27.- el gobierno federal está obligado a a fianzar sus relaciones de paz y comercio \ncon las potencias extranjeras por medio de tratados  que estén en conformidad con los principios \nde derecho público establecidos en esta constitució n.',
#  'artículo 28.- los principios, garantías y derechos reconocidos en los anteriores artículos, no \npodrán ser alterados por las leyes que reglamenten su ejercicio.',
#  'artículo 29.- el congreso no puede conceder al ejec utivo nacional, ni las legislaturas \nprovinciales a los gobernadores de provincia, facul tades extraordinarias, ni la suma del poder \npúblico, ni otorgarles sumisiones o supremacías por  las que la vida, el honor o las fortunas de los \nargentinos queden a merced de gobiernos o persona a lguna. actos de esta naturaleza llevan \nconsigo una nulidad insanable, y sujetarán a los qu e los formulen, consientan o firmen, a la \nresponsabilidad y pena de los infames traidores a l a patria.',
#  'artículo 30.- la constitución puede reformarse en e l todo o en cualquiera de sus partes. la \nnecesidad de reforma debe ser declarada por el cong reso con el voto de dos terceras partes, al \nmenos, de sus miembros; \npero no se efectuará sino por una convención convoc ada al efecto.',
#  'artículo 31.- esta constitución, las leyes de la na ción que en su consecuencia se dicten por \nel congreso y los tratados con las potencias extran jeras son la ley suprema de la nación; y las \nautoridades de cada provincia están obligadas a con formarse a ella, no obstante cualquiera \ndisposición en contrario que contengan las leyes o constituciones provinciales, salvo para la \nprovincia de buenos aires, los tratados ratificados  después del pacto de 11 de noviembre de \n1859.',
#  'artículo 32.- el congreso federal no dictará leyes que restrinjan la libertad de imprenta o \nestablezcan sobre ella la jurisdicción federal.',
#  'artículo 33.- las declaraciones, derechos y garantí as que enumera la constitución, no serán \nentendidos como negación de otros derechos y garant ías no enumerados; pero que nacen del \nprincipio de la soberanía del pueblo y de la forma republicana de gobierno.',
#  'artículo 34.- los jueces de las cortes federales no  podrán serlo al mismo tiempo de los \ntribunales de provincia, ni el servicio federal, ta nto en lo civil como en lo militar, da residencia e n \nla provincia en que se ejerza, y que no sea la del domicilio habitual del empleado, entendiéndose \nesto para los efectos de optar a empleos en la prov incia en que accidentalmente se encuentre.',
#  'artículo 35.- las denominaciones adoptadas sucesiva mente desde 1810 hasta el presente, a \nsaber: provincias unidas del río de la plata; repúb lica argentina, confederación argentina, \nserán en adelante nombres oficiales indistintamente  para la designación del gobierno y territorio \nde las provincias, empleándose las palabras "nación  argentina" en la formación y sanción de las \nleyes. \ncapítulo segundo - nuevos derechos y garantías',
#  'artículo 36.- esta constitución mantendrá su imperi o aun cuando se interrumpiere su \nobservancia por actos de fuerza contra el orden ins titucional y el sistema democrático. estos \nactos serán insanablemente nulos. sus autores serán  pasibles de la sanción prevista en el',
#  'artículo 29, inhabilitados a perpetuidad para ocupa r cargos públicos y excluidos de los beneficios \ndel indulto y la conmutación de penas. tendrán las mismas sanciones quienes, como \nconsecuencia de estos actos, usurparen funciones pr evistas para las autoridades de esta \nconstitución o las de las provincias, los que respo nderán civil y penalmente de sus actos. las \nacciones respectivas serán imprescriptibles. todos los ciudadanos tienen el derecho de \nresistencia contra quienes ejecutaren los actos de fuerza enunciados en este artículo. atentará \nasimismo contra el sistema democrático quien incurr iere en grave delito doloso contra el estado \nque conlleve enriquecimiento, quedando inhabilitado  por el tiempo que las leyes determinen para \nocupar cargos o empleos públicos. el congreso sanci onará una ley sobre ética pública para el \nejercicio de la función.',
#  'artículo 37.- esta constitución garantiza el pleno ejercicio de los derechos políticos, con \narreglo al principio de la soberanía popular y de l as leyes que se dicten en consecuencia. el \nsufragio es universal, igual, secreto y obligatorio . la igualdad real de oportunidades entre \nvarones y mujeres para el acceso a cargos electivos  y partidarios se garantizará por acciones \npositivas en la regulación de los partidos político s y en el régimen electoral.',
#  'artículo 38.- los partidos políticos son institucio nes fundamentales del sistema democrático. \nsu creación y el ejercicio de sus actividades son l ibres dentro del respeto a esta constitución, la \nque garantiza su organización y funcionamiento demo cráticos, la representación de las minorías, \nla competencia para la postulación de candidatos a cargos públicos electivos, el acceso a la \ninformación pública y la difusión de sus ideas. el estado contribuye al sostenimiento económico \nde sus actividades y de la capacitación de sus diri gentes. los partidos políticos deberán dar \npublicidad del origen y destino de sus fondos y pat rimonio.',
#  'artículo 39.- los ciudadanos tienen el derecho de i niciativa para presentar proyectos de ley \nen la cámara de diputados. el congreso deberá darle s expreso tratamiento dentro del término \nde doce meses. el congreso, con el voto de la mayor ía absoluta de la totalidad de los miembros \nde cada cámara, sancionará una ley reglamentaria qu e no podrá exigir más del tres por ciento \ndel padrón electoral nacional, dentro del cual debe rá contemplar una adecuada distribución \nterritorial para suscribir la iniciativa. no serán objeto de iniciativa popular los proyectos referido s \na reforma constitucional, tratados internacionales,  tributos, presupuesto y materia penal.',
#  'artículo 40.- el congreso, a iniciativa de la cámar a de diputados, podrá someter a consulta \npopular un proyecto de ley. la ley de convocatoria no podrá ser vetada. el voto afirmativo del \nproyecto por el pueblo de la nación lo convertirá e n ley y su promulgación será automática. el \ncongreso o el presidente de la nación, dentro de su s respectivas competencias, podrán \nconvocar a consulta popular no vinculante. en este caso el voto no será obligatorio. el congreso, \ncon el voto de la mayoría absoluta de la totalidad de los miembros de cada cámara, \nreglamentará las materias, procedimientos y oportun idad de la consulta popular.',
#  'artículo 41.- todos los habitantes gozan del derech o a un ambiente sano, equilibrado, apto \npara el desarrollo humano y para que las actividade s productivas satisfagan las necesidades \npresentes sin comprometer las de las generaciones f uturas; y tienen el deber de preservarlo. el \ndaño ambiental generará prioritariamente la obligac ión de recomponer, según lo establezca la \nley. las autoridades proveerán a la protección de e ste derecho, a la utilización racional de los \nrecursos naturales, a la preservación del patrimoni o natural y cultural y de la diversidad biológica, \ny a la información y educación ambientales. corresp onde a la nación dictar las normas que \ncontengan los presupuestos mínimos de protección, y  a las provincias, las necesarias para \ncomplementarlas, sin que aquéllas alteren las juris dicciones locales. se prohíbe el ingreso al \nterritorio nacional de residuos actual o potencialm ente peligrosos y de los radiactivos.',
#  'artículo 42.- los consumidores y usuarios de bienes  y servicios tienen derecho, en la \nrelación de consumo, a la protección de su salud, s eguridad e intereses económicos; a una \ninformación adecuada y veraz; a la libertad de elec ción y a condiciones de trato equitativo y \ndigno. las autoridades proveerán a la protección de  esos derechos, a la educación para el \nconsumo, a la defensa de la competencia contra toda  forma de distorsión de los mercados, al \ncontrol de los monopolios naturales y legales, al d e la calidad y eficiencia de los servicios \npúblicos y a la constitución de asociaciones de con sumidores y de usuarios. la legislación \nestablecerá procedimientos eficaces para la prevenc ión y solución de conflictos y los marcos \nregulatorios de los servicios públicos de competenc ia nacional, previendo la necesaria \nparticipación de las asociaciones de consumidores y  usuarios y de las provincias interesadas, en \nlos organismos de control.',
#  'artículo 43.- toda persona puede interponer acción expedita y rápida de amparo, siempre \nque no exista otro medio judicial más idóneo, contr a todo acto u omisión de autoridades públicas \no de particulares, que en forma actual o inminente lesione, restrinja, altere o amenace, con \narbitrariedad o ilegalidad manifiesta, derechos y g arantías reconocidos por esta constitución, un \ntratado o una ley. en el caso, el juez podrá declar ar la inconstitucionalidad de la norma en que se \nfunde el acto u omisión lesiva. podrán interponer e sta acción contra cualquier forma de \ndiscriminación y en lo relativo a los derechos que protegen al ambiente, a la competencia, al \nusuario y al consumidor, así como a los derechos de  incidencia colectiva en general, el afectado, \nel defensor del pueblo y las asociaciones que prope ndan a esos fines, registradas conforme a la \nley, la que determinará los requisitos y formas de su organización. toda persona podrá \ninterponer esta acción para tomar conocimiento de l os datos a ella referidos y de su finalidad, \nque consten en registros o bancos de datos públicos , o los privados destinados a proveer \ninformes, y en caso de falsedad o discriminación, p ara exigir la supresión, rectificación, \nconfidencialidad o actualización de aquéllos. \nno podrá afectarse el secreto de las fuentes de inf ormación periodística. \ncuando el derecho lesionado, restringido, alterado o amenazado fuera la libertad física, o en \ncaso de agravamiento ilegítimo en la forma o condic iones de detención, o en el de desaparición \nforzada de personas, la acción de hábeas corpus pod rá ser interpuesta por el afectado o por \ncualquiera en su favor y el juez resolverá de inmed iato, aun durante la vigencia del estado de \nsitio. \nsegunda parte - autoridades de la nación  título primero - gobierno federal  \nsección primera - del poder legislativo',
#  'artículo 44.- un congreso compuesto de dos cámaras,  una de diputados de la nación y otra \nde senadores de las provincias y de la ciudad de bu enos aires, será investido del poder \nlegislativo de la nación. \ncap. i - de la cámara de diputados',
#  'artículo 45.- la cámara de diputados se compondrá d e representantes elegidos \ndirectamente por el pueblo de las provincias, de la  ciudad de buenos aires, y de la capital en \ncaso de traslado, que se consideran a este fin como  distritos electorales de un solo estado y a \nsimple pluralidad de sufragios. el número de repres entantes será de uno por cada treinta y tres \nmil habitantes o fracción que no baje de dieciséis mil quinientos. después de la realización de \ncada censo, el congreso fijará la representación co n arreglo al mismo, pudiendo aumentar pero \nno disminuir la base expresada para cada diputado.',
#  'artículo 46.- los diputados para la primera legisla tura se nombraran en la proporción \nsiguiente: por la provincia de buenos aires, doce; por la de córdoba, seis; por la de catamarca, \ntres; por la de corrientes, cuatro; por la de entre  ríos, dos; por la de jujuy, dos; por la de \nmendoza, tres; por la de la rioja, dos; por la de s alta, tres; por la de santiago del estero, cuatro; \npor la de san juan, dos; por la de santa fe, dos; p or la de san luis, dos; y por la de tucumán, \ntres.',
#  'artículo 47.- para la segunda legislatura deberá re alizarse le censo general, y arreglarse a él \nel número de diputados; pero este censo sólo podrá renovarse cada diez años.',
#  'artículo 48.- para ser diputado se requiere haber c umplido la edad de veinticinco años, tener \ncuatro años de ciudadanía en ejercicio, y ser natur al de la provincia que lo elija, o con dos años \nde residencia inmediata en ella.',
#  'artículo 49.- por esta vez las legislaturas de las provincias reglarán los medios de hacer \nefectiva la elección directa de los diputados de la  nación: para lo sucesivo el congreso expedirá \nuna ley general.',
#  'artículo 50.- los diputados duraran en su represent ación por cuatro años, y son reelegibles; \npero la sala se renovara por mitad cada bienio; a c uyo efecto los nombrados para la primera \nlegislatura, luego que se reúnan, sortearán los que  deban salir en el primer período.',
#  'artículo 51.- en caso de vacante, el gobierno de pr ovincia, o de la capital, hace proceder a \nelección legal de un nuevo miembro.',
#  'artículo 52.- a la cámara de diputados corresponde exclusivamente la iniciativa de las leyes \nsobre contribuciones y reclutamiento de tropas.',
#  'artículo 53.- sólo ella ejerce el derecho de acusar  ante el senado al presidente, \nvicepresidente, al jefe de gabinete de ministros, a  los ministros y a los miembros de la corte \nsuprema, en las causas de responsabilidad que se in tenten contra ellos, por mal desempeño o \npor delito en el ejercicio de sus funciones; o por crímenes comunes, después de haber conocido \nde ellos y declarado haber lugar a la formación de causa por la mayoría de dos terceras partes \nde sus miembros presentes. cap. ii - del senado',
#  'artículo 54.- el senado se compondrá de tres senado res por cada provincia y tres por la \nciudad de buenos aires, elegidos en forma directa y  conjunta, correspondiendo dos bancas al \npartido político que obtenga el mayor número de vot os y la restante al partido político que le siga \nen el número de votos. cada senador tendrá un voto.',
#  'artículo 55.- son requisitos para ser elegido senad or: tener la edad de treinta años, haber \nsido seis años ciudadano de la nación, disfrutar de  una renta anual de dos mil pesos fuertes o de \nuna entrada equivalente, y ser natural de la provin cia que lo elija, o con dos años de residencia \ninmediata en ella.',
#  'artículo 56.- los senadores duran seis años en el e jercicio de su mandato, y son reelegibles \nindefinidamente, pero el senado se renovará a razón  de una tercera parte de los distritos \nelectorales cada dos años.',
#  'artículo 57.- el vicepresidente de la nación será p residente del senado; \npero no tendrá voto sino en el caso que haya empate  en la votación.',
#  'artículo 58.- el senado nombrara un presidente prov isorio que lo presida en caso de \nausencia del vicepresidente, o cuando éste ejerce l as funciones de presidente de la nación.',
#  'artículo 59.- al senado corresponde juzgar en juici o público a los acusados por la cámara de \ndiputados, debiendo sus miembros prestar juramento para este acto. cuando el acusado sea el \npresidente de la nación, el senado será presidido p or el presidente de la corte suprema. \nninguno será declarado culpable sino a mayoría de l os dos tercios de los miembros presentes.',
#  'artículo 60.- su fallo no tendrá mas efecto que des tituir al acusado, y aun declararle incapaz \nde ocupar ningún empleo de honor, de confianza o a sueldo en la nación. pero la parte \ncondenada quedara, no obstante, sujeta a acusación,  juicio y castigo conforme a las leyes ante \nlos tribunales ordinarios.',
#  'artículo 61.- corresponde también al senado autoriz ar al presidente de la nación para que \ndeclare en estado de sitio, uno o varios puntos de la república en caso de ataque exterior.',
#  'artículo 62.- cuando vacase alguna plaza de senador  por muerte, renuncia u otra causa, el \ngobierno a que corresponda la vacante hace proceder  inmediatamente a la elección de un nuevo \nmiembro. \ncap. iii - disposiciones comunes a ambas cámaras',
#  'artículo 63.- ambas cámaras se reunirán por sí mism as en sesiones ordinarias todos los \naños desde el primero de marzo hasta el treinta de noviembre. \npueden también ser convocadas extraordinariamente p or el presidente de la nación o \nprorrogadas sus sesiones.',
#  'artículo 64.- cada cámara es juez de las elecciones , derechos y títulos de sus miembros en \ncuanto a su validez. ninguna de ellas entrara en se sión sin la mayoría absoluta de sus \nmiembros; pero un número menor podrá compeler a los  miembros ausentes a que concurran a \nlas sesiones, en los términos y bajo las penas que cada cámara establecerá.',
#  'artículo 65.- ambas cámaras empiezan y concluyen su s sesiones simultáneamente. \nninguna de ellas, mientras se hallen reunidas, podr á suspender sus sesiones más de tres días, \nsin el consentimiento de la otra.',
#  'artículo 66.- cada cámara hará su reglamento, y pod rá con dos tercios de votos, corregir a \ncualquiera de sus miembros por desorden de conducta  en el ejercicio de sus funciones, o \nremoverlo por inhabilidad física o moral sobrevinie nte a su incorporación, y hasta excluirle de su \nseno; pero bastara la mayoría de uno sobre la mitad  de los presentes para decidir en las \nrenuncias que voluntariamente hicieren de sus cargo s.',
#  'artículo 67.- los senadores y diputados prestarán, en el acto de su incorporación, juramento \nde desempeñar debidamente el cargo, y de obrar en t odo en conformidad a lo que prescribe esta \nconstitución.',
#  'artículo 68.- ninguno de los miembros del congreso puede ser acusado, interrogado \njudicialmente, ni molestado por las opiniones o dis cursos que emita desempeñando su mandato \nde legislador.',
#  'artículo 69.- ningún senador o diputado, desde el d ía de su elección hasta el de su cese, \npuede ser arrestado; excepto el caso de ser sorpren dido "in fraganti" en la ejecución de algún \ncrimen que merezca pena de muerte, infamante, u otr a aflictiva; de lo que se dará cuenta a la \ncámara respectiva con al información sumaria del he cho.',
#  'artículo 70.- cuando se forme querella por escrito ante las justicias ordinarias contra \ncualquier senador o diputado, examinado el mérito d el sumario en juicio público, podrá cada \ncámara, con dos tercios de votos, suspender en sus funciones al acusado, y ponerlo a \ndisposición del juez competente para su juzgamiento .',
#  'artículo 71.- cada una de las cámaras puede hacer v enir a su sala a los ministros del poder \nejecutivo para recibir las explicaciones e informes  que estime convenientes.',
#  'artículo 72.- ningún miembro del congreso podrá rec ibir empleo o comisión del poder \nejecutivo, sin previo consentimiento de la cámara r espectiva, excepto los empleos de escala.',
#  'artículo 73.- los eclesiásticos regulares no pueden  ser miembros del congreso, ni los \ngobernadores de provincia por la de su mando.',
#  'artículo 74.- los servicios de los senadores y dipu tados son remunerados por el tesoro de la \nnación, con una dotación que señalara la ley. \ncap. iv - atribuciones del congreso',
#  'artículo 75.- corresponde al congreso: \n1. legislar en materia aduanera. establecer los der echos de importación y exportación, los \ncuales, así como las avaluaciones sobre las que rec aigan, serán uniformes en toda la nación. \n2. imponer contribuciones indirectas como facultad concurrente con las provincias. imponer \ncontribuciones directas, por tiempo determinado, pr oporcionalmente iguales en todo el territorio \nde la nación, siempre que la defensa, seguridad com ún y bien general del estado lo exijan. las \ncontribuciones previstas en este inciso, con excepc ión de la parte o el total de las que tengan \nasignación específica, con coparticipables. una ley  convenio, sobre la base de acuerdos entre la nación y las provincias, instituirá regímenes de co participación de estas contribuciones, \ngarantizando la automaticidad en la remisión de los  fondos. la distribución entre la nación, las \nprovincias y la ciudad de buenos aires y entre ésta s, se efectuará en relación directa a las \ncompetencias, servicios y funciones de cada una de ellas contemplando criterios objetivos de \nreparto; será equitativa, solidaria y dará priorida d al logro de un grado equivalente de desarrollo, \ncalidad de vida e igualdad de oportunidades en todo  el territorio nacional. la ley convenio tendrá \ncomo cámara de origen el senado y deberá ser sancio nada con la mayoría absoluta de la \ntotalidad de los miembros de cada cámara, no podrá ser modificada unilateralmente ni \nreglamentada y será aprobada por las provincias. no  habrá transferencia de competencias, \nservicios o funciones sin la respectiva reasignació n de recursos, aprobada por la ley del \ncongreso cuando correspondiere y por la provincia i nteresada o la ciudad de buenos aires, en \nsu caso. un organismo fiscal federal tendrá a su ca rgo el control y fiscalización de la ejecución \nde lo establecido en este inciso, según lo determin e la ley, la que deberá asegurar la \nrepresentación de todas las provincias y la ciudad de buenos aires en su composición. \n3. establecer y modificar asignaciones específicas de recursos coparticipables, por tiempo \ndeterminado, por la ley especial aprobada por la ma yoría absoluta de la totalidad de los \nmiembros de cada cámara. \n4. contraer empréstitos sobre el crédito de la naci ón. \n5. disponer del uso y de la enajenación de las tier ras de propiedad nacional. \n6. establecer y reglamentar un banco federal con fa cultad de emitir moneda, así como otros \nbancos nacionales. \n7. arreglar el pago de la deuda interior y exterior  de la nación. \n8. fijar anualmente, conforme a las pautas establec idas en el tercer párrafo del inciso 2 de este \nartículo, el presupuesto general de gastos y cálcul o de recursos de la administración nacional, en \nbase al programa general de gobierno y al plan de i nversiones públicas y aprobar o desechar la \ncuenta de inversión. \n9. acordar subsidios del tesoro nacional a las prov incias, cuyas rentas no alcancen, según sus \npresupuestos, a cubrir sus gastos ordinarios. \n10. reglamentar la libre navegación de los ríos int eriores, habilitar los puertos que considere \nconvenientes, y crear o suprimir aduanas. \n11. hacer sellar moneda, fijar su valor y el de las  extranjeras; y adoptar un sistema uniforme de \npesos y medidas para toda la nación. \n12. dictar los códigos civil, comercial, penal, de minería y del trabajo y seguridad social, en \ncuerpos unificados o separados, sin que tales códig os alteren las jurisdicciones locales, \ncorrespondiendo su aplicación a los tribunales fede rales o provinciales, según que las cosas o \nlas personas cayeren bajo sus respectivas jurisdicc iones; y especialmente leyes generales para \ntoda la nación sobre naturalización y nacionalidad,  con sujeción al principio de nacionalidad \nnatural y por opción en beneficio de la argentina; así como sobre bancarrotas, sobre falsificación \nde la moneda corriente y documentos públicos del es tado, y las que requiera el  ...
#  'artículo 76.- se prohíbe la delegación legislativa en el poder ejecutivo, salvo en materias \ndeterminadas de administración o de emergencia públ ica, con plazo fijado para su ejercicio y \ndentro de las bases de la delegación que el congres o establezca. la caducidad resultante del \ntranscurso del plazo previsto en el párrafo anterio r no importará revisión de las relaciones \njurídicas nacidas al amparo de las normas dictadas en consecuencia de la delegación legislativa. \ncap. v - de la formación y sanción de las leyes',
#  'artículo 77.- las leyes pueden tener principio en c ualquiera de las cámaras del congreso, \npor proyectos presentados por sus miembros o por el  poder ejecutivo, salvo las excepciones que \nestablece esta constitución.',
#  'artículo 78.- aprobado un proyecto de ley por la cá mara de su origen, pasa para su discusión \na la otra cámara. aprobado por ambas, pasa al poder  ejecutivo de la nación para su examen; y \nsi también obtiene su aprobación, lo promulga como ley.',
#  'artículo 79.- cada cámara, luego de aprobar un proy ecto de ley en general, puede delegar \nen sus comisiones la aprobación en particular del p royecto, con el voto de la mayoría absoluta \ndel total de sus miembros. la cámara podrá, con igu al número de votos, dejar sin efecto la \ndelegación y retomar el trámite ordinario. la aprob ación en comisión requerirá el voto de la \nmayoría absoluta del total de sus miembros. una vez  aprobado el proyecto en comisión, se \nseguirá el trámite ordinario.',
#  'artículo 80.- se reputa aprobado por el poder ejecu tivo todo proyecto no devuelto en el \ntérmino de diez días útiles. los proyectos desechad os parcialmente no podrán ser aprobados en \nla parte restante. sin embargo, las partes no obser vadas solamente podrán ser promulgadas si \ntienen autonomía normativa y su aprobación parcial no altera el espíritu ni la unidad del proyecto \nsancionado por el congreso. en este caso será de ap licación el procedimiento previsto para los \ndecretos de necesidad y urgencia.',
#  'artículo 81.- ningún proyecto de ley desechado tota lmente por una de las cámaras podrá \nrepetirse en las sesiones de aquel año. ninguna de las cámaras puede desechar totalmente un \nproyecto que hubiera tenido origen en ella y luego hubiese sido adicionado o enmendado por la \ncámara revisora. si el proyecto fuere objeto de adi ciones o correcciones por la cámara revisora, \ndeberá indicarse el resultado de la votación a fin de establecer si tales adiciones o correcciones \nfueron realizadas por mayoría absoluta de los prese ntes o por las dos terceras partes de los \npresentes. la cámara de origen podrá por mayoría ab soluta de los presentes aprobar el \nproyecto con las adiciones o correcciones introduci das o insistir en la redacción originaria, a \nmenos que las adiciones o correcciones las haya rea lizado la revisora por dos terceras partes de \nlos presentes. en este último caso, el proyecto pas ará al poder ejecutivo con las adiciones o \ncorrecciones de la cámara revisora, salvo que la cá mara de origen insista en su redacción \noriginaria con el voto de las dos terceras partes d e los presentes. la cámara de origen no podrá \nintroducir nuevas adiciones o correcciones a las re alizadas por la cámara revisora.',
#  'artículo 82.- la voluntad de cada cámara debe manif estarse expresamente; se excluye, en \ntodos los casos, la sanción tácita o ficta.',
#  'artículo 83.- desechado en el todo o en parte un pr oyecto por el poder ejecutivo, vuelve con \nsus objeciones a la cámara de su origen: esta lo di scute de nuevo, y si lo confirma por mayoría \nde dos tercios de votos, pasa otra vez a la cámara de revisión. si ambas cámaras lo sancionan \npor igual mayoría, el proyecto es ley y pasa al pod er ejecutivo para su promulgación. las \nvotaciones de ambas cámaras serán en este caso nomi nales, por si o por no; y tanto los \nnombres y fundamentos de los sufragantes, como las objeciones del poder ejecutivo, se \npublicarán inmediatamente por la prensa. si las cám aras difieren sobre las objeciones, el \nproyecto no podrá repetirse en las sesiones de aqué l año.',
#  'artículo 84.- en la sanción de las leyes se usara d e esta fórmula: el senado y cámara de \ndiputados de la nación argentina reunidos en congre so, decretan o sancionan con fuerza de \nley. \ncap. vi - de la auditoría general de la nación',
#  'artículo 85.- el control externo del sector público  nacional en sus aspectos patrimoniales, \neconómicos, financieros y operativos será una atrib ución propia del poder legislativo. el examen \ny la opinión del poder legislativo sobre el desempe ño y situación general de la administración \npública estarán sustentados en los dictámenes de la  auditoría general de la nación. este \norganismo de asistencia técnica del congreso, con a utonomía funcional, se integrará del modo \nque establezca la ley que reglamenta su creación y funcionamiento, que deberá ser aprobada \npor mayoría absoluta de los miembros de cada cámara . el presidente del organismo será \ndesignado a propuesta del partido político de oposi ción con mayor número de legisladores en el \ncongreso. tendrá a su cargo el control de legalidad , gestión y auditoría de toda la actividad de la \nadministración pública centralizada y descentraliza da, cualquiera fuera su modalidad de \norganización, y las demás funciones que la ley le o torgue. \nintervendrá necesariamente en el trámite de aprobac ión o rechazo de las cuentas de percepción \ne inversión de los fondos públicos. \ncap. vii - del defensor del pueblo.',
#  'artículo 86.- el defensor del pueblo es un órgano i ndependiente instituido en el ámbito del \ncongreso de la nación, que actuará con plena autono mía funcional, sin recibir instrucciones de \nninguna autoridad. su misión es la defensa y protec ción de los derechos humanos y demás \nderechos, garantías e intereses tutelados en esta c onstitución y las leyes, ante hechos, actos u \nomisiones de la administración; y el control del ej ercicio de las funciones administrativas \npúblicas. el defensor del pueblo tiene legitimación  procesal. es designado y removido por el \ncongreso con el voto de las dos terceras partes de los miembros presentes de cada una de las \ncámaras. goza de las inmunidades y privilegios de l os legisladores. durará en su cargo cinco \naños, pudiendo ser nuevamente designado por una sol a vez. la organización y el \nfuncionamiento de esta institución serán regulados por una ley especial. \nsección segunda - del poder ejecutivo  \ncap. i - de su naturaleza y duración',
#  'artículo 87.- el poder ejecutivo de la nación será desempeñado por un ciudadano con el \ntítulo de "presidente de la nación argentina".',
#  'artículo 88.- en caso de enfermedad, ausencia de la  capital, muerte, renuncia o destitución \ndel presidente, el poder ejecutivo será ejercido po r el vicepresidente de la nación. en caso de \ndestitución, muerte, dimisión o inhabilidad del pre sidente y vicepresidente de la nación, el congreso determinará qué funcionario público ha de desempeñar la presidencia, hasta que haya \ncesado la causa de la inhabilidad o un nuevo presid ente sea electo.',
#  'artículo 89.- para ser elegido presidente o vicepre sidente de la nación, se requiere haber \nnacido en el territorio argentino, o ser hijo de ci udadano nativo, habiendo nacido en país \nextranjero; y las demás calidades exigidas para ser  electo senador.',
#  'artículo 90.- el presidente y vicepresidente duran en sus funciones el término de cuatro años \ny podrán ser reelegidos o sucederse recíprocamente por un solo período consecutivo. si han \nsido reelectos o se han sucedido recíprocamente no pueden ser elegidos para ninguno de \nambos cargos, sino con el intervalo de un período.',
#  'artículo 91.- el presidente de la nación cesa en el  poder el día mismo en que expira su \nperíodo de cuatro años; sin que evento alguno que l o haya interrumpido, pueda ser motivo de \nque se le complete más tarde.',
#  'artículo 92.- el presidente y vicepresidente disfru tan de un sueldo pagado por el tesoro de la \nnación, que no podrá ser alterado en el período de sus nombramientos. durante el mismo \nperíodo no podrán ejercer otro empleo, ni recibir n ingún otro emolumento de la nación, ni de \nprovincia alguna.',
#  'artículo 93.- al tomar posesión de su cargo el pres idente y vicepresidente prestarán \njuramento, en manos del presidente del senado y ant e el congreso reunido en asamblea, \nrespetando sus creencias religiosas de: "desempeñar  con lealtad y patriotismo el cargo de \npresidente (o vicepresidente) de la nación y observ ar y hacer observar fielmente la constitución \nde la nación argentina." \ncap. ii - forma y tiempo de elección de presidente y vicepresidente',
#  'artículo 94.- el presidente y el vicepresidente de la nación serán elegidos directamente por el \npueblo, en doble vuelta, según lo establece esta co nstitución. a este fin el territorio nacional \nconformará un distrito único.',
#  'artículo 95.- la elección se efectuará dentro de lo s dos meses anteriores a la conclusión del \nmandato del presidente en ejercicio.',
#  'artículo 96.- la segunda vuelta electoral, si corre spondiere, se realizará entre las dos \nfórmulas de candidatos más votadas, dentro de los t reinta días de celebrada la anterior.',
#  'artículo 97.- cuando la fórmula que resultare más v otada en la primera vuelta, hubiere \nobtenido más del cuarenta y cinco por ciento de los  votos afirmativos válidamente emitidos, sus \nintegrantes serán proclamados como presidente y vic epresidente de la nación.',
#  'artículo 98.- cuando la fórmula que resultare más v otada en la primera vuelta hubiere \nobtenido el cuarenta por ciento por lo menos de los  votos afirmativos, válidamente emitidos y, \nademás, existiere una diferencia mayor de diez punt os porcentuales respecto del total de los \nvotos afirmativos válidamente emitidos sobre la fór mula que le sigue en número de votos, sus \nintegrantes serán proclamados como presidente y vic epresidente de la nación. \ncap. iii - atribuciones del poder ejecutivo',
#  'artículo 99.- el presidente de la nación tiene las siguientes atribuciones: 1. es el jefe supremo de la nación, jefe del gobier no y responsable político de la administración \ngeneral del país. \n2. expide las instrucciones y reglamentos que sean necesarios para la ejecución de las leyes de \nla nación, cuidando de no alterar su espíritu con e xcepciones reglamentarias. \n3. participa de la formación de las leyes con arreg lo a la constitución, las promulga y hace \npublicar. el poder ejecutivo no podrá en ningún cas o bajo pena de nulidad absoluta e insanable, \nemitir disposiciones de carácter legislativo. solam ente cuando circunstancias excepcionales \nhicieran imposible seguir los trámites ordinarios p revistos por esta constitución para la sanción \nde las leyes, y no se trate de normas que regulen m ateria penal, tributaria, electoral o el régimen \nde los partidos políticos, podrá dictar decretos po r razones de necesidad y urgencia, los que \nserán decididos en acuerdo general de ministros que  deberán refrendarlos, conjuntamente con el \njefe de gabinete de ministros. \nel jefe de gabinete de ministros personalmente y de ntro de los diez días someterá la medida a \nconsideración de la comisión bicameral permanente, cuya composición deberá respetar la \nproporción de las representaciones políticas de cad a cámara. esta comisión elevará su \ndespacho en un plazo de diez días al plenario de ca da cámara para su expreso tratamiento, el \nque de inmediato considerarán las cámaras. una ley especial sancionada con la mayoría \nabsoluta de la totalidad de los miembros de cada cá mara regulará el trámite y los alcances de la \nintervención del congreso. \n4. nombra los magistrados de la corte suprema con a cuerdo del senado por dos tercios de sus \nmiembros presentes, en sesión pública, convocada al  efecto. nombra los demás jueces de los \ntribunales federales inferiores en base a una propu esta vinculante en terna del consejo de la \nmagistratura, con acuerdo del senado, en sesión púb lica, en la que se tendrá en cuenta la \nidoneidad de los candidatos. un nuevo nombramiento,  precedido de igual acuerdo, será \nnecesario para mantener en el cargo a cualquiera de  esos magistrados, una vez que cumplan la \nedad de setenta y cinco años. todos los nombramient os de magistrados cuya edad sea la \nindicada o mayor se harán por cinco años, y podrán ser repetidos indefinidamente, por el mismo \ntrámite. \n5. puede indultar o conmutar las penas por delitos sujetos a la jurisdicción federal, previo informe \ndel tribunal correspondiente, excepto en los casos de acusación por la cámara de diputados. \n6. concede jubilaciones, retiros, licencias y pensi ones conforme a las leyes de la nación. \n7. nombra y promueve a los embajadores, ministros p lenipotenciarios y encargados de negocios \ncon acuerdo del senado; por sí solo nombra y remuev e la jefe de gabinete de ministros y a los \ndemás ministros del despacho, los oficiales de su s ecretaría, los agentes consulares y los \nempleados cuyo nombramiento no está reglado de otra  forma por esta constitución. \n8. hace anualmente la apertura de las sesiones del congreso, reunidas al efecto ambas \ncámaras, dando cuenta en esta ocasión del estado de  la nación, de las reformas prometidas por \nla constitución, y recomendando a su consideración las medidas que juzgue necesarias y \nconvenientes. \n9. prorroga las sesiones ordinarias del congreso, o  lo convoca a sesiones extraordinarias, \ncuando un grave interés de orden o de progreso lo r equiera. \n10. supervisa el ejercicio de la facultad del jefe de gabinete de ministros respecto de la \nrecaudación de las rentas de la nación y de su inve rsión, con arreglo a la ley o presupuesto de \ngastos nacionales. 11. concluye y firma tratados, concordatos y otras negociaciones requeridas para el \nmantenimiento de buenas relaciones con las organiza ciones internacionales y las naciones \nextranjeras, recibe sus ministros y admite sus cóns ul ...
#  'artículo 23. \n17. puede pedir al jefe de gabinete de ministros y a los jefes de todos los ramos y departamentos \nde la administración, y por su conducto a los demás  empleados, los informes que crea \nconvenientes, y ellos están obligados a darlos. \n18. puede ausentarse del territorio de la nación, c on permiso del congreso. en el receso de \néste, sólo podrá hacerlo sin licencia por razones j ustificadas de servicio público. \n19. puede llenar las vacantes de los empleos, que r equieran el acuerdo del senado, y que \nocurran durante su receso, por medio de nombramient os en comisión que expirarán al fin de la \npróxima legislatura. \n20. decreta la intervención federal a una provincia  o a la ciudad de buenos aires en caso de \nreceso del congreso, y debe convocarlo simultáneame nte para su tratamiento. \ncap. iv - del jefe de gabinete y demás ministros de l poder ejecutivo',
#  'artículo 100.- el jefe de gabinete de ministros y l os demás ministros secretarios cuyo número \ny competencia será establecido por una ley especial , tendrán a su cargo el despacho de los \nnegocios de la nación, y refrendarán y legalizarán los actos del presidente por medio de su \nfirma, sin cuyo requisito carecen de eficacia. al j efe de gabinete de ministros, con \nresponsabilidad política ante el congreso de la nac ión, le corresponde: \n1. ejercer la administración general del país. \n2. expedir los actos y reglamentos que sean necesar ios para ejercer las facultades que le \natribuye este artículo y aquéllas que le delegue el  presidente de la nación, con el refrendo del \nministro secretario del ramo al cual el acto o regl amento se refiera. \n3. efectuar los nombramientos de los empleados de l a administración, excepto los que \ncorrespondan al presidente. 4. ejercer las funciones y atribuciones que le dele gue el presidente de la nación y, en acuerdo \nde gabinete, resolver sobre las materias que le ind ique el poder ejecutivo, o por su propia \ndecisión, en aquéllas que por su importancia estime  necesario, en el ámbito de su competencia. \n5. coordinar, preparar y convocar las reuniones de gabinete de ministros, presidiéndolas en caso \nde ausencia del presidente. \n6. enviar al congreso los proyectos de ley de minis terios y de presupuesto nacional, previo \ntratamiento en acuerdo de gabinete y aprobación del  poder ejecutivo. \n7. hacer recaudar las rentas de la nación y ejecuta r la ley de presupuesto nacional. \n8. refrendar los decretos reglamentarios de las ley es, los decretos que dispongan la prórroga de \nlas sesiones ordinarias del congreso o la convocato ria de sesiones extraordinarias y los \nmensajes del presidente que promuevan la iniciativa  legislativa. \n9. concurrir a las sesiones del congreso y particip ar en sus debates, pero no votar. \n10. una vez que se inicien las sesiones ordinarias del congreso, presentar junto a los restantes \nministros una memoria detallada del estado de la na ción en lo relativo a los negocios de los \nrespectivos departamentos. \n11. producir los informes y explicaciones verbales o escritos que cualquiera de las cámaras \nsolicite al poder ejecutivo. \n12. refrendar los decretos que ejercen facultades d elegadas por el congreso, los que estarán \nsujetos al control de la comisión bicameral permane nte. \n13. refrendar conjuntamente con los demás ministros  los decretos de necesidad y urgencia y los \ndecretos que promulgan parcialmente leyes. \nsometerá personalmente y dentro de los diez días de  su sanción estos decretos a consideración \nde la comisión bicameral permanente. el jefe de gab inete de ministros no podrá desempeñar \nsimultáneamente otro ministerio.',
#  'artículo 101.- el jefe de gabinete de ministros deb e concurrir al congreso al menos una vez \npor mes, alternativamente a cada una de sus cámaras , para informar de la marcha del gobierno, \nsin perjuicio de lo dispuesto en el',
#  'artículo 71. pu ede ser interpelado a los efectos del tratamiento \nde una moción de censura, y ser removido por el vot o de la mayoría absoluta de los miembros \nde cualquiera de las cámaras.',
#  'artículo 102.- cada ministro es responsable de los actos que legaliza; y solidariamente de los \nque acuerda con sus colegas.',
#  'artículo 103.- los ministros no pueden por sí solos , en ningún caso, tomar resoluciones a \nexcepción de lo concerniente al régimen económico y  administrativo de sus respectivos \ndepartamentos.',
#  'artículo 104.- luego que el congreso abra sus sesio nes, deberán los ministros del despacho \npresentarle una memoria detallada del estado de la nación en lo relativo a los negocios de sus \nrespectivos departamentos.',
#  'artículo 105.- no pueden ser senadores ni diputados , sin hacer dimisión de sus empleos de \nministros.',
#  'artículo 106.- pueden los ministros concurrir a las  sesiones del congreso y tomar parte en \nsus debates, pero no votar.',
#  'artículo 107.- gozarán por sus servicios de un suel do establecido por la ley, que no podrá \nser aumentado ni disminuido en favor o perjuicio de  los que se hallen en ejercicio. \nsección tercera - del poder judicial  \ncap. i - de su naturaleza y duración',
#  'artículo 108.- el poder judicial de la nación será ejercido por una corte suprema de justicia, \ny por los demás tribunales inferiores que el congre so estableciese en el territorio de la nación.',
#  'artículo 109.- en ningún caso el presidente de la n ación puede ejercer funciones judiciales, \narrogarse el conocimiento de causas pendientes o re stablecer las fenecidas.',
#  'artículo 110.- los jueces de la corte suprema y de los tribunales inferiores de la nación \nconservarán sus empleos mientras dure su buena cond ucta, y recibirán por sus servicios una \ncompensación que determinara la ley, y que no podrá  ser disminuida en manera alguna, \nmientras permaneciesen en sus funciones.',
#  'artículo 111.- ninguno podrá ser miembro de la cort e suprema de justicia, sin ser abogado \nde la nación con ocho años de ejercicio, y tener la s calidades requeridas para ser senador.',
#  'artículo 112.- en la primera instalación de la cort e suprema, los individuos nombrados \nprestarán juramento en manos del presidente de la n ación de desempeñar sus obligaciones, \nadministrando justicia bien y legalmente, y en conf ormidad a lo que prescribe la constitución. en \nlo sucesivo lo prestarán ante el presidente de la m isma corte.',
#  'artículo 113.- la corte suprema dictará su reglamen to interior y nombrará todos sus \nempleados.',
#  'artículo 114.- el consejo de la magistratura, regul ado por una ley especial sancionada por la \nmayoría absoluta de la totalidad de los miembros de  cada cámara, tendrá a su cargo la \nselección de los magistrados y la administración de l poder judicial. el consejo será integrado \nperiódicamente de modo que se procure el equilibrio  entre la representación de los órganos \npolíticos resultantes de la elección popular, de lo s jueces de todas las instancias y de los \nabogados de la matrícula federal. será integrado, a simismo, por otras personas del ámbito \nacadémico y científico, en el número y la forma que  indique la ley. serán sus atribuciones: \n1. seleccionar mediante concursos públicos los post ulantes a las magistraturas inferiores. \n2. emitir propuestas en ternas vinculantes, para el  nombramiento de los magistrados de los \ntribunales inferiores. \n3. administrar los recursos y ejecutar el presupues to que la ley asigne a la administración de \njusticia. \n4. ejercer facultades disciplinarias sobre magistra dos. 5. decidir la apertura del procedimiento de remoció n de magistrados, en su caso ordenar la \nsuspensión, y formular la acusación correspondiente . \n6. dictar los reglamentos relacionados con la organ ización judicial y todos aquéllos que sean \nnecesarios para asegurar la independencia de los ju eces y la eficaz prestación de los servicios \nde justicia.',
#  'artículo 115.- los jueces de los tribunales inferio res de la nación serán removidos por las \ncausales expresadas en el',
#  'artículo 53, por un jurad o de enjuiciamiento integrado por \nlegisladores, magistrados y abogados de la matrícul a federal. su fallo, que será irrecurrible, no \ntendrá más efecto que destituir al acusado. pero la  parte condenada quedará no obstante sujeta \na acusación, juicio y castigo conforme a las leyes ante los tribunales ordinarios. corresponderá \narchivar las actuaciones y, en su caso, reponer al juez suspendido, si transcurrieren ciento \nochenta días contados desde la decisión de abrir el  procedimiento de remoción, sin que haya \nsido dictado el fallo. en la ley especial a que se refiere el',
#  'artículo 114, se determinará la \nintegración y procedimiento de este jurado. \ncap. ii - atribuciones del poder judicial',
#  'artículo 116.- corresponde a la corte suprema y a l os tribunales inferiores de la nación, el \nconocimiento y decisión de todas las causas que ver sen sobre puntos regidos por la \nconstitución, y por las leyes de la nación, con la reserva hecha en el inciso 11 del',
#  'artículo 67: y \npor los tratados con las naciones extranjeras; de l as causas concernientes a embajadores, \nministros públicos y cónsules extranjeros; de las c ausas de almirantazgo y jurisdicción marítima; \nde los asuntos en que la nación sea parte; de las c ausas que se susciten entre dos o mas \nprovincias; entre una provincia y los vecinos de di ferentes provincias; y entre una provincia o sus \nvecinos, contra un estado o ciudadano extranjero.',
#  'artículo 117.- en estos casos la corte suprema ejer cerá su jurisdicción por apelación según \nlas reglas y excepciones que prescriba el congreso;  \npero en todos los asuntos concernientes a embajador es, ministros y cónsules extranjeros, y en \nlos que alguna provincia fuese parte, la ejercerá o riginaria y exclusivamente.',
#  'artículo 118.- todos los juicios criminales ordinar ios, que no se deriven del derecho de \nacusación concedido a la cámara de diputados se ter minaran por jurados, luego que se \nestablezca en la república esta institución. la act uación de estos juicios se hará en la misma \nprovincia donde se hubiere cometido el delito; pero  cuando este se cometa fuera de los límites \nde la nación contra el derecho de gentes, el congre so determinara por una ley especial el lugar \nen que haya de seguirse le juicio.',
#  'artículo 119.- la traición contra la nación consist irá únicamente en tomar las armas contra \nella, o en unirse a sus enemigos prestándoles ayuda  y socorro. el congreso fijara por una ley \nespecial la pena de este delito; \npero ella no pasara e la persona del delincuente, n i la infamia del reo se transmitirá a sus \nparientes de cualquier grado. \nsección cuarta - del ministerio público',
#  'artículo 120.- el ministerio público es un órgano i ndependiente con autonomía funcional y \nautarquía financiera, que tiene por función promove r la actuación de la justicia en defensa de la \nlegalidad, de los intereses generales de la socieda d, en coordinación con las demás autoridades de la república. está integrado por un procurador g eneral de la nación y un defensor general de \nla nación y los demás miembros que la ley establezc a. sus miembros gozan de inmunidades \nfuncionales e intangibilidad de remuneraciones. \ntítulo segundo - gobiernos de provincia',
#  'artículo 121.- las provincias conservan todo el pod er no delegado por esta constitución al \ngobierno federal, y el que expresamente se hayan re servado por pactos especiales al tiempo de \nsu incorporación.',
#  'artículo 122.- se dan sus propias instituciones loc ales y se rigen por ellas. \neligen sus gobernadores, sus legisladores y demás f uncionarios de provincia, sin intervención \ndel gobierno federal.',
#  'artículo 123.- cada provincia dicta su propia const itución, conforme a lo dispuesto por el',
#  'artículo 5 asegurando la autonomía municipal y regl ando su alcance y contenido en el orden \ninstitucional, político, administrativo, económico y financiero.',
#  'artículo 124.- las provincias podrán crear regiones  para el desarrollo económico y social y \nestablecer órganos con facultades para el cumplimie nto de sus fines y podrán también celebrar \nconvenios internacionales en tanto no sean incompat ibles con la política exterior de la nación y \nno afecten las facultades delegadas al gobierno fed eral o el crédito público de la nación; con \nconocimiento del congreso nacional. \nla ciudad de buenos aires tendrá el régimen que se establezca a tal efecto. corresponde a las \nprovincias el dominio originario de los recursos na turales existentes en su territorio.',
#  'artículo 125.- las provincias pueden celebrar trata dos parciales para fines de administración \nde justicia, de intereses económicos y trabajos de utilidad común, con conocimiento del \ncongreso federal; y promover su industria, la inmig ración, la construcción de ferrocarriles y \ncanales navegables, la colonización de tierras de p ropiedad provincial, la introducción y \nestablecimiento de nuevas industrias, la importació n de capitales extranjeros y la exploración de \nsus ríos, por leyes protectoras de estos fines, y c on sus recursos propios. las provincias y la \nciudad de buenos aires pueden conservar organismos de seguridad social para los empleados \npúblicos y los profesionales; y promover el progres o económico, el desarrollo humano, la \ngeneración de empleo, la educación, la ciencia, el conocimiento y la cultura.',
#  'artículo 126.- las provincias no ejercen el poder d elegado a la nación. \nno pueden celebrar tratados parciales de carácter p olítico; ni expedir leyes sobre comercio, o \nnavegación interior o exterior; ni establecer aduan as provinciales; ni acuñar moneda; ni \nestablecer bancos con facultad de emitir billetes, sin autorización del congreso federal; ni dictar \nlos códigos civil, comercial, penal y de minería de spués que el congreso los haya sancionado; ni \ndictar especialmente leyes sobre ciudadanía y natur alización, bancarrotas, falsificación de \nmoneda o documentos del estado; ni establecer derec hos de tonelaje; ni armar buques de guerra \no levantar ejércitos, salvo el caso de invasión ext erior o de un peligro tan inminente que no \nadmita dilación dando luego cuenta al gobierno fede ral; ni nombrar o recibir agentes \nextranjeros.',
#  'artículo 127.- ninguna provincia puede declarar, ni  hacer la guerra a otra provincia. sus \nquejas deben ser sometidas a la corte suprema de ju sticia y dirimidas por ella. sus hostilidades de hecho son actos de guerra civil, calificados de sedición o asonada, que el gobierno federal \ndebe sofocar y reprimir conforme a la ley.',
#  'artículo 128.- los gobernadores de provincia son ag entes naturales del gobierno federal \npara hacer cumplir la constitución y las leyes de l a nación.',
#  'artículo 129.- la ciudad de buenos aires tendrá un régimen de gobierno autónomo, con \nfacultades propias de legislación y jurisdicción, y  su jefe de gobierno será elegido directamente \npor el pueblo de la ciudad. \nuna ley garantizará los intereses del estado nacion al, mientras la ciudad de buenos aires sea \ncapital de la nación. en el marco de lo dispuesto e n este artículo, el congreso de la nación \nconvocará a los habitantes de la ciudad de buenos a ires para que, mediante los representantes \nque elijan a ese efecto, dicten el estatuto organiz ativo de sus instituciones.']

# %% [markdown]
# ## Function Calling: Camera‑Implied Task Classification (Argentina’s Constitution)
#
# We define a function-calling schema to classify, for each article of Argentina’s Constitution, whether it assigns or implies a task/role to: (a) Congress, (b) Senate, (c) both Congress and Senate, or (d) neither. The tool returns a structured output with the target, whether it’s explicit or inferred, an evidence snippet, and a short rationale.

# %%
def camera_task_parser(items):
    def _norm_target(val: str) -> str:
        v = (val or "").strip().lower()
        if v in {
            "congress", "congreso", "congreso de la nación", "congreso de la nacion",
            "diputados", "cámara de diputados", "camara de diputados",
        }:
            return "congress"
        if v in {
            "senate", "senado", "cámara de senadores", "camara de senadores",
        }:
            return "senate"
        if v in {
            "both", "ambas", "ambos", "ambas cámaras", "ambas camaras",
            "congress and senate", "congreso y senado", "senado y congreso",
            "ambas cámaras del congreso", "ambas camaras del congreso",
        }:
            return "both"
        if v in {"neither", "ninguna", "ninguno", "none", "no aplica"}:
            return "neither"
        return "neither"

    def _norm_eoi(val: str) -> str:
        v = (val or "").strip().lower()
        if v in {"explicit", "explícita", "explicita", "expreso", "expresa"}:
            return "explicit"
        return "inferred"

    parsed = []
    for it in items:
        tgt = _norm_target(it.get("target"))
        eoi = _norm_eoi(it.get("explicit_or_inferred"))
        evi = (it.get("evidence", "") or "").strip()
        if len(evi) > 240:
            evi = evi[:240]
        rat = (it.get("rationale", "") or "").strip()
        parsed.append({
            "article_id": it.get("article_id", ""),
            "target": tgt,
            "explicit_or_inferred": eoi,
            "evidence": evi,
            "rationale": rat,
        })
    return parsed


def run_camera_task_conversation(article_text, article_id=None, model=None):
    # Resolve model lazily to avoid NameError if MODEL isn't defined yet
    if model is None:
        model = globals().get("MODEL", "llama3-70b-8192")

    # Ensure Groq client exists (handles fresh kernels)
    cli = globals().get("client")
    if cli is None:
        try:
            from groq import Groq
        except Exception as e:
            raise RuntimeError("Groq SDK is not available; please run the Groq setup cell.") from e
        api = globals().get("api_key")
        if not api:
            raise RuntimeError("Groq client is not initialized and GROQ_API_KEY is missing.")
        globals()["client"] = Groq(api_key=api)
        cli = globals()["client"]

    # System and user prompts geared to constitutional analysis in Spanish.
    messages = [
        {
            "role": "system",
            "content": (
                "Eres un LLM experto en derecho constitucional argentino. "
                "Analizas artículos de la Constitución Nacional de Argentina y determinas si el artículo asigna o implica una tarea/rol a las cámaras legislativas: Congreso, Senado, ambas, o ninguna. "
                "Si la referencia es indirecta pero razonablemente deducible (p. ej., menciones a 'Congreso' o 'Senado', o a funciones propias como sanción de leyes, juicio político, acuerdos, etc.), clasifícala como 'inferred'. "
                "Cuando el texto menciona explícitamente 'Congreso' o 'Senado' con una atribución específica, clasifícala como 'explicit'."
            ),
        },
        {
            "role": "user",
            "content": (
                f"Analiza el siguiente artículo y clasifica la tarea implicada en relación con las cámaras.\n\n"
                f"Artículo ID: {article_id or ''}\n"
                f"Texto: {article_text}"
            ),
        },
    ]

    tools = [
        {
            "type": "function",
            "function": {
                "name": "camera_task_parser",
                "description": (
                    "Dado el texto de un artículo constitucional argentino, devuelve una lista con una única entrada que clasifica si el artículo asigna/implica una tarea a: 'congress', 'senate', 'both', o 'neither'. "
                    "Incluye si la atribución es 'explicit' o 'inferred', cita una evidencia breve del texto y explica brevemente el criterio."
                ),
                "parameters": {
                    "type": "object",
                    "properties": {
                        "items": {
                            "type": "array",
                            "description": (
                                "Una lista con una única clasificación para el artículo analizado."
                            ),
                            "items": {
                                "type": "object",
                                "properties": {
                                    "article_id": {
                                        "type": "string",
                                        "description": "Identificador del artículo (p. ej., 'Artículo 1', o índice numérico).",
                                    },
                                    "target": {
                                        "type": "string",
                                        "description": (
                                            "A qué cámara(s) asigna o implica la tarea: 'congress' (Congreso de la Nación), 'senate' (Senado), 'both' (ambas cámaras), o 'neither' (ninguna). Es obligatorio elegir una de estas cuatro."
                                        ),
                                    },
                                    "explicit_or_inferred": {
                                        "type": "string",
                                        "description": (
                                            "Especifica si la atribución es 'explicit' (mencionada expresamente) o 'inferred' (deducida razonablemente)."
                                        ),
                                    },
                                    "evidence": {
                                        "type": "string",
                                        "description": "Fragmento breve del artículo que respalda la clasificación (máx. ~240 caracteres).",
                                    },
                                    "rationale": {
                                        "type": "string",
                                        "description": (
                                            "Explicación corta (1-3 frases) de por qué el artículo implica la tarea para esa(s) cámara(s)."
                                        ),
                                    },
                                },
                                # No required fields inside to avoid tool validation failures; defaults handled in parser
                            },
                        },
                    },
                    "required": ["items"],
                },
            },
        }
    ]

    def _call(messages):
        return cli.chat.completions.create(
            model=model,
            messages=messages,
            tools=tools,
            tool_choice="auto",
            max_tokens=2048,
        )

    try:
        response = _call(messages)
    except Exception:
        # Retry once with stricter instruction to avoid empty fields
        messages.insert(1, {
            "role": "system",
            "content": (
                "Usa la herramienta 'camera_task_parser' y rellena todos los campos. "
                "Elige exactamente uno en target: congress | senate | both | neither. "
                "No dejes valores vacíos; si dudas, usa 'neither' y marca 'inferred'."
            )
        })
        response = _call(messages)

    response_message = response.choices[0].message
    tool_calls = response_message.tool_calls

    if tool_calls:
        available_functions = {"camera_task_parser": camera_task_parser}
        # Extend messages with assistant's function call
        messages.append(response_message)
        for tc in tool_calls:
            fn_name = tc.function.name
            fn = available_functions[fn_name]
            fn_args = json.loads(tc.function.arguments)
            fn_response = fn(items=fn_args.get("items", []))
            messages.append({
                "role": "function",
                "name": fn_name,
                "content": json.dumps(fn_response),
            })
        second = cli.chat.completions.create(model=model, messages=messages)
        return second.choices[0].message.content, fn_response

    # If no tool call, fall back to plain text
    return response_message.content, []


# Convenience: classify all parsed articles

def classify_all_camera_tasks(articles):
    results = []
    for idx, art in enumerate(articles, start=1):
        text = art.strip()
        if not text:
            continue
        completion, structured = run_camera_task_conversation(text, article_id=f"Artículo {idx}")
        results.append({
            "article_id": f"Artículo {idx}",
            "completion": completion,
            "structured": structured,
        })
    return results

# %%
# Quick smoke test on first articles (optional)
preview = articles_list[:5] if isinstance(articles_list, list) else []
results = classify_all_camera_tasks(preview)

# Normalize to a flat DataFrame for inspection
rows = []
for r in results:
    structured = r.get("structured") or []
    if structured and isinstance(structured, list):
        for item in structured:
            # Each tool return from camera_task_parser is a list, so unpack
            if isinstance(item, list):
                for sub in item:
                    rows.append({
                        "article_id": sub.get("article_id", r.get("article_id")),
                        "target": sub.get("target"),
                        "explicit_or_inferred": sub.get("explicit_or_inferred"),
                        "evidence": sub.get("evidence"),
                        "rationale": sub.get("rationale"),
                    })
            elif isinstance(item, dict):
                rows.append({
                    "article_id": item.get("article_id", r.get("article_id")),
                    "target": item.get("target"),
                    "explicit_or_inferred": item.get("explicit_or_inferred"),
                    "evidence": item.get("evidence"),
                    "rationale": item.get("rationale"),
                })
    else:
        rows.append({
            "article_id": r.get("article_id"),
            "target": None,
            "explicit_or_inferred": None,
            "evidence": None,
            "rationale": r.get("completion"),
        })

df_camera_tasks = pd.DataFrame(rows)
df_camera_tasks.head()
# Out:
#    article_id    target explicit_or_inferred  \
# 0  Artículo 1   neither             inferred
# 1  Artículo 2   neither             inferred
# 2  Artículo 3  congress             explicit
# 3  Artículo 4  congress             explicit
# 4  Artículo 5  congress             inferred
#
#                                             evidence  \
# 0  Adopta para su gobierno la forma representativ...
# 1  El gobierno federal sostiene el culto católico...
# 2                  por una ley especial del Congreso
# 3  del congreso general, y de los empréstitos y o...
# 4                   dictará para sí una constitución
#
#                                            rationale
# 0  El artículo establece la forma de gobierno, lo...
# 1  No se menciona explícitamente la intervención ...
# 2  El artículo especifica que una ley especial de...
# 3  El artículo menciona explícitamente al Congres...
# 4  La provincia dictará una constitución que aseg...
